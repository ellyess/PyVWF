# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../ninja-reimplementation/data/wind_data/UK/renewable_power_plants_UK_filtered.csv')

# %%
data
# Out:
#      electrical_capacity energy_source_level_1 energy_source_level_2
# 0                    1.3      Renewable energy                  Wind  \
# 1                    2.7      Renewable energy                  Wind
# 2                   31.0      Renewable energy                  Wind
# 3                    4.8      Renewable energy                  Wind
# 4                    9.6      Renewable energy                  Wind
# ..                   ...                   ...                   ...
# 773                  6.2      Renewable energy                  Wind
# 774                 88.4      Renewable energy                  Wind
# 775                  1.8      Renewable energy                  Wind
# 776                 29.9      Renewable energy                  Wind
# 777               1200.0      Renewable energy                  Wind
#
#      energy_source_level_3 technology data_source nuts_1_region nuts_2_region
# 0                      NaN    Onshore        BEIS           UKE          UKE2  \
# 1                      NaN    Onshore        BEIS           UKC          UKC2
# 2                      NaN    Onshore        BEIS           UKL          UKL2
# 3                      NaN    Onshore        BEIS           UKD          UKD1
# 4                      NaN    Onshore        BEIS           UKD          UKD4
# ..                     ...        ...         ...           ...           ...
# 773                    NaN    Onshore        BEIS           UKH          UKH1
# 774                    NaN    Onshore        BEIS           UKM          UKM9
# 775                    NaN    Onshore        BEIS           UKL          UKL2
# 776                    NaN    Onshore        BEIS           UKM          UKM6
# 777                    NaN   Offshore        BEIS           UKH          UKH1
#
#     nuts_3_region       lon  ...   country commissioning_date
# 0           UKE22 -1.914154  ...   England         1992-01-06  \
# 1           UKC21 -1.495191  ...   England         1992-01-12
# 2           UKL24 -3.430831  ...     Wales         1993-01-01
# 3           UKD12 -3.135725  ...   England         1993-01-01
# 4           UKD46 -2.149984  ...   England         1993-01-02
# ..            ...       ...  ...       ...                ...
# 773         UKH12 -0.287708  ...   England         2019-09-05
# 774         UKM95 -4.036105  ...  Scotland         2019-09-15
# 775         UKL23 -3.200769  ...     Wales         2019-11-01
# 776         UKM61 -4.373161  ...  Scotland         2020-01-03
# 777         UKH16  1.420739  ...   England         2020-02-06
#
#     solar_mounting_type chp capacity_individual_turbine number_of_turbines
# 0                   NaN NaN                         0.3                  4  \
# 1                   NaN NaN                         0.3                  9
# 2                   NaN NaN                         0.3                103
# 3                   NaN NaN                         0.4                 12
# 4                   NaN NaN                         0.4                 24
# ..                  ...  ..                         ...                ...
# 773                 NaN NaN                         3.0                  3
# 774                 NaN NaN                         3.4                 26
# 775                 NaN NaN                         0.9                  2
# 776                 NaN NaN                         2.3                 13
# 777                 NaN NaN                         7.0                174
#
#                       site_name  uk_beis_id                        operator
# 0             Chelker Reservoir        2921                 Yorkshire Water  \
# 1       Blyth Harbour Wind Farm        3659           Border Wind Farms Ltd
# 2            Llandinam Windfarm        3057                   CELTPOWER LTD
# 3                   Kirkby Moor        2713               Npower Renewables
# 4         Coal Clough Wind Farm        3079  Renewable Energy Systems (RES)
# ..                          ...         ...                             ...
# 773       Common Barn Wind Farm        4076                  TCI Renewables
# 774         Kype Muir Wind Farm        4643                Banks Renewables
# 775                    Kingspan        4790                        Kingspan
# 776  Coire Na Cloiche Wind Farm        3846                       RockbySea
# 777   Hornsea 1 - Heron & Njord        2525   Orsted (formerly Dong Energy)
#
#      comment
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 773      NaN
# 774      NaN
# 775      NaN
# 776      NaN
# 777      NaN
#
# [778 rows x 25 columns]

# %%
columns = ['country','technology','lon','lat','electrical_capacity','number_of_turbines','capacity_individual_turbine', 'commissioning_date']

# %%
data = data[columns]
data
# Out:
#       country technology       lon        lat  electrical_capacity
# 0     England    Onshore -1.914154  53.962432                  1.3  \
# 1     England    Onshore -1.495191  55.125438                  2.7
# 2       Wales    Onshore -3.430831  52.442104                 31.0
# 3     England    Onshore -3.135725  54.257491                  4.8
# 4     England    Onshore -2.149984  53.749662                  9.6
# ..        ...        ...       ...        ...                  ...
# 773   England    Onshore -0.287708  52.277348                  6.2
# 774  Scotland    Onshore -4.036105  55.632652                 88.4
# 775     Wales    Onshore -3.200769  53.289670                  1.8
# 776  Scotland    Onshore -4.373161  57.769620                 29.9
# 777   England   Offshore  1.420739  53.681541               1200.0
#
#      number_of_turbines  capacity_individual_turbine commissioning_date
# 0                     4                          0.3         1992-01-06
# 1                     9                          0.3         1992-01-12
# 2                   103                          0.3         1993-01-01
# 3                    12                          0.4         1993-01-01
# 4                    24                          0.4         1993-01-02
# ..                  ...                          ...                ...
# 773                   3                          3.0         2019-09-05
# 774                  26                          3.4         2019-09-15
# 775                   2                          0.9         2019-11-01
# 776                  13                          2.3         2020-01-03
# 777                 174                          7.0         2020-02-06
#
# [778 rows x 8 columns]

# %%
data.electrical_capacity.sum()
# Out:
# 23020.0
